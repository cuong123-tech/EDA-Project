# %% [markdown]
# # Exploratory Data Analysis (EDA)
# ## Objective
# Find and summarize the statistics of the data frame.
#
# Propose insights about the data.
# ## Tools
# Pandas
#
# Numpy

# %%
#Import libaries
import pandas as pd
import numpy as np

# %%
#Read the data and print out some rows
data = pd.read_csv('Cleaned_COVID_stats.csv', encoding='latin1')
data.head()
# Out:
#    Country  TotalCases    TotalDeaths   TotalRecovered  NewRecovered  \
# 0      USA   111820082 1219487.000000 109814428.000000      0.000000
# 1    India    45035393  533570.000000         0.000000      0.000000
# 2   France    40138560  167642.000000  39970918.000000      0.000000
# 3  Germany    38828995  183027.000000  38240600.000000      0.000000
# 4   Brazil    38743918  711380.000000  36249161.000000      0.000000
#
#      ActiveCases    Serious  TotalCases_per_1M  Deaths_per_1M  \
# 0  786167.000000 940.000000      333985.000000    3642.000000
# 1       0.000000   0.000000       32016.000000     379.000000
# 2       0.000000   0.000000      612013.000000    2556.000000
# 3  405368.000000   0.000000      462891.000000    2182.000000
# 4 1783377.000000   0.000000      179908.000000    3303.000000
#
#          TotalTests   Tests_per_1M        Population      Continent  \
# 0 1186851502.000000 3544901.000000  334805269.000000  North America
# ...

# %%
#Copy the data to avoid modifying the original one
data_copy = data.copy()

# %%
data_copy
# Out:
#             Country  TotalCases    TotalDeaths   TotalRecovered  NewRecovered  \
# 0               USA   111820082 1219487.000000 109814428.000000      0.000000
# 1             India    45035393  533570.000000         0.000000      0.000000
# 2            France    40138560  167642.000000  39970918.000000      0.000000
# 3           Germany    38828995  183027.000000  38240600.000000      0.000000
# 4            Brazil    38743918  711380.000000  36249161.000000      0.000000
# ..              ...         ...            ...              ...           ...
# 226         Tokelau          80       0.000000         0.000000      0.000000
# 227    Vatican City          29       0.000000        29.000000      0.000000
# 228  Western Sahara          10       1.000000         9.000000      0.000000
# 229      MS Zaandam           9       2.000000         7.000000      0.000000
# 230          Total:   704753890 7010681.000000 675619811.000000    790.000000
#
# ...

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              231 non-null    object
#  1   TotalCases           231 non-null    int64
#  2   TotalDeaths          231 non-null    float64
#  3   TotalRecovered       231 non-null    float64
#  4   NewRecovered         231 non-null    float64
#  5   ActiveCases          231 non-null    float64
#  6   Serious              231 non-null    float64
#  7   TotalCases_per_1M    231 non-null    float64
#  8   Deaths_per_1M        231 non-null    float64
#  9   TotalTests           231 non-null    float64
#  10  Tests_per_1M         231 non-null    float64
#  11  Population           231 non-null    float64
#  12  Continent            228 non-null    object
#  13  1_Case_every_X_ppl   231 non-null    float64
#  14  1_Death_every_X_ppl  231 non-null    float64
# ...

# %%
data_copy.describe()
# Out:
#             TotalCases    TotalDeaths   TotalRecovered  NewRecovered  \
# count       231.000000     231.000000       231.000000    231.000000
# mean    6099586.484848   60675.714286   5349820.017316      6.987013
# std    47242731.438876  472073.112854  45236680.325368     62.223963
# min           9.000000       0.000000         0.000000      0.000000
# 25%       26366.000000     185.500000      2189.500000      0.000000
# 50%      206897.000000    1974.000000     58947.000000      0.000000
# 75%     1377176.000000   14688.000000   1042623.500000      0.000000
# max   704753890.000000 7010681.000000 675619811.000000    790.000000
#
#           ActiveCases      Serious  TotalCases_per_1M  Deaths_per_1M  \
# count      231.000000   231.000000         231.000000     231.000000
# mean    121732.181818   163.077922      201583.006061    1242.516883
# std    1461417.482720  2289.560454      205823.113535    1306.514039
# ...

# %% [markdown]
# It seems like the row "Total" was counted in the info() function so that we should delete this row

# %%
#Drop the last row
data_copy = data_copy.drop(230)

# %%
#Set display numbers in the dataset as full numbers instead of scientific notation
pd.set_option('display.float_format', '{:.6f}'.format)
data_copy.describe()
# Out:
#             TotalCases    TotalDeaths   TotalRecovered  NewRecovered  \
# count       230.000000     230.000000       230.000000    230.000000
# mean    3061959.078261   30458.300000   2435602.665217      3.582609
# std    10041685.538284  109456.993049   9215279.112187     34.637482
# min           9.000000       0.000000         0.000000      0.000000
# 25%       26275.500000     184.250000      2059.750000      0.000000
# 50%      205066.000000    1972.500000     56762.500000      0.000000
# 75%     1352372.250000   14369.500000   1033344.750000      0.000000
# max   111820082.000000 1219487.000000 109814428.000000    390.000000
#
#          ActiveCases    Serious  TotalCases_per_1M  Deaths_per_1M  \
# count     230.000000 230.000000         230.000000     230.000000
# mean    26072.765217  12.508696      202066.352174    1244.008696
# std    148389.877013  71.322855      206140.591151    1309.166397
# min         0.000000   0.000000           0.000000       0.000000
# ...

# %% [markdown]
# ### Insights
# 1. In all columns, the values of mean are much larger than that of median, so it suggests the right-skewed graphs. The mean is over 3M, but the median is just around 200K cases,this means there are some super high values that pull the mean upward.
#
# 2. The high standard deviation suggests that the data points are spread out over a wide range of values, indicating great variability from the mean.
#
# 3. If Q2 to Q3 > Q1 to Q2, the data may be right-skewed (tail on the right).

# %%
data_copy.info()
#All values are non-null and in correct data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              230 non-null    object
#  1   TotalCases           230 non-null    int64
#  2   TotalDeaths          230 non-null    float64
#  3   TotalRecovered       230 non-null    float64
#  4   NewRecovered         230 non-null    float64
#  5   ActiveCases          230 non-null    float64
#  6   Serious              230 non-null    float64
#  7   TotalCases_per_1M    230 non-null    float64
#  8   Deaths_per_1M        230 non-null    float64
#  9   TotalTests           230 non-null    float64
#  10  Tests_per_1M         230 non-null    float64
#  11  Population           230 non-null    float64
#  12  Continent            228 non-null    object
#  13  1_Case_every_X_ppl   230 non-null    float64
#  14  1_Death_every_X_ppl  230 non-null    float64
# ...

# %%
#Calculate the skewness of Data in columns
data_copy.select_dtypes(np.number).skew()
# Out:
# TotalCases             6.954985
# TotalDeaths            7.508510
# TotalRecovered         8.133684
# NewRecovered          10.533133
# ActiveCases            9.138263
# Serious               10.472014
# TotalCases_per_1M      0.880857
# Deaths_per_1M          1.256177
# TotalTests             7.331883
# Tests_per_1M           3.595337
# Population            11.218939
# 1_Case_every_X_ppl    15.015022
# 1_Death_every_X_ppl    8.676508
# 1_Test_every_X_ppl     4.162013
# Active_Cases_per_1M    4.159173
# dtype: float64

# %% [markdown]
# All the skew values are greater than 0 means that all the graphs are right-skewed.

# %% [markdown]
# ### Conclusion
# The large different between mean and median suggest the skew graphs.
#
# There are six groups of data we can group: Asia, Europe, Africa, North America, South America, Australia/Oceania.
#
# We can also group the data by continents, but we will leave it for the data visualization part.
# ### Next Steps
# Data Visualization
